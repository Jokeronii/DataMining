# %% [markdown]
# import library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("/content/drive/MyDrive/tugas datmin/Data Covid19.csv")
dataset
# Out:
#            Province/State  Country/Region       Last Update  Confirmed  \
# 0                   Anhui  Mainland China   1/22/2020 17:00          1
# 1                 Beijing  Mainland China   1/22/2020 17:00         14
# 2               Chongqing  Mainland China   1/22/2020 17:00          6
# 3                  Fujian  Mainland China   1/22/2020 17:00          1
# 4                   Gansu  Mainland China   1/22/2020 17:00          0
# ...                   ...             ...               ...        ...
# 236012  Zaporizhia Oblast         Ukraine  28/02/2021 05.22      69504
# 236013            Zeeland     Netherlands  28/02/2021 05.22      16480
# 236014           Zhejiang  Mainland China  28/02/2021 05.22       1321
# 236015    Zhytomyr Oblast         Ukraine  28/02/2021 05.22      50582
# 236016       Zuid-Holland     Netherlands  28/02/2021 05.22     255335
#
#         Deaths  Recovered
# 0            0          0
# 1            0          0
# 2            0          0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236017 entries, 0 to 236016
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Province/State  173972 non-null  object
#  1   Country/Region  236017 non-null  object
#  2   Last Update     236017 non-null  object
#  3   Confirmed       236017 non-null  int64
#  4   Deaths          236017 non-null  int64
#  5   Recovered       236017 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 10.8+ MB

# %%
dataset['Last Update'].unique()
# Out:
# array(['1/22/2020 17:00', '1/23/20 17:00', '1/24/20 17:00', ...,
#        '26/02/2021 05.22', '27/02/2021 05.22', '28/02/2021 05.22'],
#       dtype=object)

# %%
last_update='28/02/2021 05.22'
dataset[dataset['Last Update']==last_update]
# Out:
#            Province/State  Country/Region       Last Update  Confirmed  \
# 235253                NaN     Afghanistan  28/02/2021 05.22      55707
# 235254                NaN         Albania  28/02/2021 05.22     106215
# 235255                NaN         Algeria  28/02/2021 05.22     112960
# 235256                NaN         Andorra  28/02/2021 05.22      10849
# 235257                NaN          Angola  28/02/2021 05.22      20782
# ...                   ...             ...               ...        ...
# 236012  Zaporizhia Oblast         Ukraine  28/02/2021 05.22      69504
# 236013            Zeeland     Netherlands  28/02/2021 05.22      16480
# 236014           Zhejiang  Mainland China  28/02/2021 05.22       1321
# 236015    Zhytomyr Oblast         Ukraine  28/02/2021 05.22      50582
# 236016       Zuid-Holland     Netherlands  28/02/2021 05.22     255335
#
#         Deaths  Recovered
# 235253    2443      49288
# 235254    1775      68969
# 235255    2979      77976
# ...

# %%
unique_countries = dataset[dataset.Confirmed>0]['Country/Region'].unique()
unique_countries.sort()
unique_countries
# Out:
# array([' Azerbaijan', "('St. Martin',)", 'Afghanistan', 'Albania',
#        'Algeria', 'Andorra', 'Angola', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahamas, The', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei',
#        'Bulgaria', 'Burkina Faso', 'Burma', 'Burundi', 'Cabo Verde',
#        'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Channel Islands', 'Chile',
#        'Colombia', 'Comoros', 'Congo (Brazzaville)', 'Congo (Kinshasa)',
#        'Costa Rica', 'Croatia', 'Cuba', 'Curacao', 'Cyprus',
#        'Czech Republic', 'Denmark', 'Diamond Princess', 'Djibouti',
#        'Dominica', 'Dominican Republic', 'East Timor', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
# ...

# %%
country_confirmed_case = []
for i in unique_countries:
  country_confirmed_case.append(dataset[dataset.Confirmed>0][dataset['Country/Region']==i][dataset['Last Update']==last_update].Confirmed.sum())
# Out:
# <ipython-input-65-8f8591534bbe>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   country_confirmed_case.append(dataset[dataset.Confirmed>0][dataset['Country/Region']==i][dataset['Last Update']==last_update].Confirmed.sum())

# %%
print(set(zip(unique_countries,country_confirmed_case)))
# Out:
# {('Bahamas', 8519), ('Gambia', 4691), ('Pakistan', 579973), ('Guatemala', 174335), ("('St. Martin',)", 0), ('Hong Kong', 10983), ('Micronesia', 1), ('Saint Vincent and the Grenadines', 1556), ('Japan', 431093), ('Grenada', 148), ('Mongolia', 2907), ('Solomon Islands', 18), ('El Salvador', 59866), ('Uruguay', 57362), ('San Marino', 3716), ('Haiti', 12430), ('Macau', 48), ('Liberia', 2010), ('Holy See', 27), ('Republic of the Congo', 0), ('Iran', 1623159), ('Saint Barthelemy', 0), ('Taiwan', 954), ('Thailand', 25951), ('Sri Lanka', 82890), ('Panama', 340445), ('Ivory Coast', 32631), ('Libya', 132458), ('Vanuatu', 1), ('Timor-Leste', 111), ('Guam', 0), ('Burkina Faso', 11982), ('Venezuela', 138739), ('The Bahamas', 0), ('Guadeloupe', 0), ('Saint Lucia', 3356), ('Azerbaijan', 234267), ('Gambia, The', 0), ('Norway', 70826), ('India', 11096731), ('Nicaragua', 6445), ('Serbia', 456450), ('Seychelles', 2592), ('Central African Republic', 5004), ('Denmark', 211420), ('Maldives', 19597), ('Gre
# ...

# %%
unique_province = dataset['Province/State'][dataset.Confirmed>1].unique()
unique_province
# Out:
# array(['Beijing', 'Chongqing', 'Guangdong', 'Guangxi', 'Hainan', 'Henan',
#        'Hubei', 'Hunan', 'Jiangxi', 'Liaoning', 'Shandong', 'Shanghai',
#        'Sichuan', 'Tianjin', 'Zhejiang', nan, 'Anhui', 'Fujian', 'Gansu',
#        'Guizhou', 'Heilongjiang', 'Hong Kong', 'Jiangsu', 'Macau',
#        'Shaanxi', 'Xinjiang', 'Yunnan', 'Jilin', 'Taiwan', 'Ningxia',
#        'Hebei', 'Inner Mongolia', 'Shanxi', 'California', 'Qinghai',
#        'New South Wales', 'Bavaria', 'Ontario', 'Victoria', 'Queensland',
#        'Illinois', 'Chicago, IL', 'South Australia', 'San Benito, CA',
#        'Santa Clara, CA', 'Toronto, ON', 'British Columbia',
#        'Cruise Ship', 'Diamond Princess cruise ship',
#        'San Diego County, CA', 'Ashland, NE', 'Travis, CA',
#        'From Diamond Princess', 'Lackland, TX',
#        'Omaha, NE (From Diamond Princess)',
#        'Travis, CA (From Diamond Princess)',
#        'Lackland, TX (From Diamond Princess)',
# ...

# %%
province_confirmed_case = []
for i in unique_province:
  province_confirmed_case.append(dataset[dataset.Confirmed > 0][dataset['Province/State']==i][dataset['Last Update']==last_update].Confirmed.sum())
# Out:
# <ipython-input-68-f426917beec8>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   province_confirmed_case.append(dataset[dataset.Confirmed > 0][dataset['Province/State']==i][dataset['Last Update']==last_update].Confirmed.sum())

# %%
print(set(zip(unique_province,province_confirmed_case)))
# Out:
# {('Choco', 6533), ('Kumamoto', 3441), ('Kalmykia Republic', 18960), ('Nagaland', 12199), ('Ivanovo Oblast', 30476), ('Puerto Rico', 100044), ('Guadeloupe', 9968), ('Caqueta', 17018), ('Mato Grosso do Sul', 180986), ('British Virgin Islands', 153), ('Zacatecas', 27416), ('Gujarat', 269482), ('Tennessee', 773887), ('Maule', 42859), ('Uttar Pradesh', 603427), ('Namur', 40351), ('Kochi', 884), ('Port Quarantine', 2230), ('Ontario', 304962), ('Murcia', 106200), ('Lackland, TX (From Diamond Princess)', 0), ('Kiev Oblast', 75338), ('Jamtland Harjedalen', 6822), ('Netherlands', 0), ('Anhui', 994), ('Chiapas', 9991), ('Prince Edward Island', 120), ('Australian Capital Territory', 118), ('Azad Jammu and Kashmir', 10198), ('Lipetsk Oblast', 24555), ('Novgorod Oblast', 27084), ('Rivne Oblast', 48779), ('Friesland', 26180), ('Edmonton, Alberta', 0), ('Gelderland', 121556), ('Kaliningrad Oblast', 28111), ('Smolensk Oblast', 26131), ('Kansas', 295997), ('Kirov Oblast', 36366), ('Bermuda', 705), ('P
# ...

# %% [markdown]
# cek ada data yg nan atau tidak,jika ada ditampung pada array nan_indices

# %%
nan_indices = []
for i in range(len(unique_province)):
  if type(unique_province[i])==float:
    nan_indices.append(i)

# %%
unique_province = list(unique_province)
province_confirmed_case = list(province_confirmed_case)

# %%
for i in nan_indices:
  unique_province.pop(i)
  province_confirmed_case.pop(i)

unique_province
# Out:
# ['Beijing',
#  'Chongqing',
#  'Guangdong',
#  'Guangxi',
#  'Hainan',
#  'Henan',
#  'Hubei',
#  'Hunan',
#  'Jiangxi',
#  'Liaoning',
#  'Shandong',
#  'Shanghai',
#  'Sichuan',
#  'Tianjin',
#  'Zhejiang',
#  'Anhui',
#  'Fujian',
#  'Gansu',
#  'Guizhou',
#  'Heilongjiang',
#  'Hong Kong',
#  'Jiangsu',
#  'Macau',
#  'Shaanxi',
#  'Xinjiang',
#  'Yunnan',
#  'Jilin',
#  'Taiwan',
#  'Ningxia',
#  'Hebei',
#  'Inner Mongolia',
#  'Shanxi',
#  'California',
#  'Qinghai',
#  'New South Wales',
#  'Bavaria',
#  'Ontario',
#  'Victoria',
#  'Queensland',
#  'Illinois',
#  'Chicago, IL',
#  'South Australia',
#  'San Benito, CA',
#  'Santa Clara, CA',
#  'Toronto, ON',
#  'British Columbia',
#  'Cruise Ship',
#  'Diamond Princess cruise ship',
#  'San Diego County, CA',
#  'Ashland, NE',
#  'Travis, CA',
#  'From Diamond Princess',
#  'Lackland, TX',
#  'Omaha, NE (From Diamond Princess)',
#  'Travis, CA (From Diamond Princess)',
#  'Lackland, TX (From Diamond Princess)',
# ...

# %%
plt.figure(figsize=(30,30))
plt.barh(unique_countries,country_confirmed_case)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.pie(country_confirmed_case)
plt.legend(unique_countries,loc='best')
plt.show()
